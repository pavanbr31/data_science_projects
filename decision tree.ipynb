# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DF = pd.read_csv('diabetes1.csv')
print(DF.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = DF.drop(columns = 'Outcome',axis=1)
y = DF['Outcome']
print(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(x)
# Out:
# StandardScaler()

# %%
from sklearn.model_selection import train_test_split
x_tr,x_te,y_tr,y_te=train_test_split(x,y,test_size=0.2,stratify=y,random_state=5)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,accuracy_score
from mlxtend.plotting import plot_confusion_matrix
#clf = tree.DecisionTreeClassifier()
dtree_c=DecisionTreeClassifier(random_state=4)
dtree_c.fit(x_tr,y_tr)
dtree_pred=dtree_c.predict(x_te)
cm=confusion_matrix(y_te,dtree_pred)
ac=accuracy_score(dtree_pred,y_te)

# %%
print(cm)
# Out:
# [[75 25]
#  [23 31]]

# %%
print(ac)
# Out:
# 0.6883116883116883
